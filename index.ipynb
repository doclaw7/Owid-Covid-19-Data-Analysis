# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

data = pd.read_csv('owid-covid-data.csv')

# %%
df = data

# checking the dataset information
print("The dataset columns are:")
display(df.columns)

print("\nThe dataset Rows are: ")
display(df.head())

#identifying the missing values
print("\nThis are the total missing values: ")
display(df.isnull().sum())
# Out:
# The dataset columns are:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
df_filtered = df[df['location'] == 'Kenya']

# %%
# getting specific data from kenya
print("The Data from kenya is: ")
display(df_filtered)
# Out:
# The Data from kenya is:
#        iso_code continent location        date  total_cases  new_cases  \
# 157787      KEN    Africa    Kenya  2020-01-03          NaN        0.0
# 157788      KEN    Africa    Kenya  2020-01-04          NaN        0.0
# 157789      KEN    Africa    Kenya  2020-01-05          NaN        0.0
# 157790      KEN    Africa    Kenya  2020-01-06          NaN        0.0
# 157791      KEN    Africa    Kenya  2020-01-07          NaN        0.0
# ...         ...       ...      ...         ...          ...        ...
# 159167      KEN    Africa    Kenya  2023-10-14     343999.0        0.0
# 159168      KEN    Africa    Kenya  2023-10-15     343999.0        0.0
# 159169      KEN    Africa    Kenya  2023-10-16     343999.0        0.0
# 159170      KEN    Africa    Kenya  2023-10-17     343999.0        0.0
# 159171      KEN    Africa    Kenya  2023-10-18     343999.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
# getting specific data from India
df_filteredInd = df[df['location'] == 'India']
print("\nThe Data from India is: ")
display(df_filteredInd)
# Out:
# The Data from India is:
#        iso_code continent location        date  total_cases  new_cases  \
# 139773      IND      Asia    India  2020-01-03          NaN        0.0
# 139774      IND      Asia    India  2020-01-04          NaN        0.0
# 139775      IND      Asia    India  2020-01-05          NaN        0.0
# 139776      IND      Asia    India  2020-01-06          NaN        0.0
# 139777      IND      Asia    India  2020-01-07          NaN        0.0
# ...         ...       ...      ...         ...          ...        ...
# 141158      IND      Asia    India  2023-10-19          NaN        NaN
# 141159      IND      Asia    India  2023-10-20          NaN        NaN
# 141160      IND      Asia    India  2023-10-21          NaN        NaN
# 141161      IND      Asia    India  2023-10-22          NaN        NaN
# 141162      IND      Asia    India  2023-10-23          NaN        NaN
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
# getting specific data from japan
df_filteredJPA = df[df['location'] == 'Japan']
print("\nThe Data from Japan is: ")


# Display the data from Japan in a table format
display(df_filteredJPA)
# Out:
# The Data from Japan is:
#        iso_code continent location        date  total_cases  new_cases  \
# 152247      JPN      Asia    Japan  2020-01-03          NaN        0.0
# 152248      JPN      Asia    Japan  2020-01-04          NaN        0.0
# 152249      JPN      Asia    Japan  2020-01-05          NaN        0.0
# 152250      JPN      Asia    Japan  2020-01-06          NaN        0.0
# 152251      JPN      Asia    Japan  2020-01-07          NaN        0.0
# ...         ...       ...      ...         ...          ...        ...
# 153627      JPN      Asia    Japan  2023-10-14   33803572.0        0.0
# 153628      JPN      Asia    Japan  2023-10-15   33803572.0        0.0
# 153629      JPN      Asia    Japan  2023-10-16   33803572.0        0.0
# 153630      JPN      Asia    Japan  2023-10-17   33803572.0        0.0
# 153631      JPN      Asia    Japan  2023-10-18   33803572.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
# getting specific data from China
df_filteredChin = df[df['location'] == 'China']
print("\nThe Data from China is: ")
display(df_filteredChin)
# Out:
# The Data from China is:
#       iso_code continent location        date  total_cases  new_cases  \
# 60962      CHN      Asia    China  2020-01-03          NaN        0.0
# 60963      CHN      Asia    China  2020-01-04          1.0        1.0
# 60964      CHN      Asia    China  2020-01-05          1.0        0.0
# 60965      CHN      Asia    China  2020-01-06          4.0        3.0
# 60966      CHN      Asia    China  2020-01-07          4.0        0.0
# ...        ...       ...      ...         ...          ...        ...
# 62342      CHN      Asia    China  2023-10-14   99315684.0        NaN
# 62343      CHN      Asia    China  2023-10-15   99315684.0        NaN
# 62344      CHN      Asia    China  2023-10-16   99315684.0        NaN
# 62345      CHN      Asia    China  2023-10-17   99315684.0        NaN
# 62346      CHN      Asia    China  2023-10-18   99315684.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
# Drop rows where any of the specified columns have missing values
df_cleaned = df.dropna(subset=['date', 'location', 'total_cases'])

# Preview the cleaned data
display(df_cleaned)
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 54          AFG      Asia  Afghanistan  2020-02-26          1.0        1.0
# 55          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 56          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# 57          AFG      Asia  Afghanistan  2020-02-29          1.0        0.0
# 58          AFG      Asia  Afghanistan  2020-03-01          1.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 350080      ZWE    Africa     Zimbabwe  2023-10-14     265808.0        0.0
# 350081      ZWE    Africa     Zimbabwe  2023-10-15     265808.0        0.0
# 350082      ZWE    Africa     Zimbabwe  2023-10-16     265808.0        0.0
# 350083      ZWE    Africa     Zimbabwe  2023-10-17     265808.0        0.0
# 350084      ZWE    Africa     Zimbabwe  2023-10-18     265808.0        0.0
#
# ...

# %%
# Filter for the three countries
countries = ['Kenya', 'United States', 'India']
filtered_df = df[df['location'].isin(countries)]


# Drop rows with missing data
filtered_df = filtered_df.dropna(subset=['date', 'total_cases'])

# Convert 'date' to datetime
filtered_df['date'] = pd.to_datetime(filtered_df['date'])

# Pivot to get countries as columns
pivot_df = filtered_df.pivot(index='date', columns='location', values='total_cases')

# Plot
plt.figure(figsize=(14, 6))
for country in countries:
    plt.plot(pivot_df.index, pivot_df[country], label=country)

plt.title('Total COVID-19 Cases Over Time: Kenya vs India vs USA')
plt.xlabel('Date')
plt.ylabel('Total Cases')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt



# Drop rows with missing 'date' or 'new_cases'
filtered_df = filtered_df.dropna(subset=['date', 'new_cases'])

# Convert 'date' column to datetime
filtered_df['date'] = pd.to_datetime(filtered_df['date'])

# Pivot data to have countries as columns
pivot_df = filtered_df.pivot(index='date', columns='location', values='new_cases')

# Plot the daily new cases
plt.figure(figsize=(14, 6))
for country in countries:
    plt.plot(pivot_df.index, pivot_df[country], label=country)

plt.title('Daily New COVID-19 Cases: Kenya vs USA vs India')
plt.xlabel('Date')
plt.ylabel('New Cases')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Calculatind the total death rates
df = df.dropna(subset=['total_cases', 'total_deaths'])
df = df[df['total_cases'] > 0]

# Create a new column for death rate
df['death_rate'] = df['total_deaths'] / df['total_cases']

display(df['death_rate'])
# Out:
# 81        0.025000
# 82        0.023810
# 83        0.013514
# 84        0.013514
# 85        0.025000
#             ...
# 350080    0.021512
# 350081    0.021512
# 350082    0.021512
# 350083    0.021512
# 350084    0.021512
# Name: death_rate, Length: 290479, dtype: float64

# %%
#plotting Deaths overtime
plt.figure(figsize=(14, 6))
for country in countries:
    plt.plot(pivot_df.index, pivot_df[country], label=country)

plt.title('Total COVID-19 Deaths Over Time: Kenya vs India vs USA')
plt.xlabel('Date')
plt.ylabel('Total Deaths')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# 2. Bar Chart - Average alcohol content by quality
plt.figure(figsize=(14, 6))

df_grouped = filtered_df.groupby('location')['total_cases'].sum()


df_grouped.plot(kind='bar', color='skyblue')
plt.title('Countries vs Total cases')
plt.xlabel('Countries')
plt.ylabel('Total Cases')
plt.tight_layout()
plt.show()

# %%
# cummulative vaccinations over time for selected countries
# Filter data for cumulative vaccinations
vaccination_columns = ['date', 'location', 'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated']
vaccination_data = filtered_df[vaccination_columns].dropna()

# Pivot data for cumulative vaccinations
vaccination_pivot = vaccination_data.pivot(index='date', columns='location', values='total_vaccinations')

# Plot cumulative vaccinations over time
plt.figure(figsize=(14, 6))
for country in countries:
    plt.plot(vaccination_pivot.index, vaccination_pivot[country], label=country)

plt.title('Cumulative COVID-19 Vaccinations Over Time')
plt.xlabel('Date')
plt.ylabel('Total Vaccinations')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Calculating % vaccinated population
population_data = filtered_df[['location', 'population']].drop_duplicates()
vaccinated_population = vaccination_data.groupby('location')['people_vaccinated'].max()
population_data.set_index('location', inplace=True)
vaccinated_percentage = (vaccinated_population / population_data['population']) * 100

# Plot pie charts for vaccinated vs. unvaccinated
for country in countries:
    vaccinated = vaccinated_percentage[country]
    unvaccinated = 100 - vaccinated
    plt.figure(figsize=(6, 6))
    plt.pie([vaccinated, unvaccinated], labels=['Vaccinated', 'Unvaccinated'], autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
    plt.title(f'Vaccinated vs. Unvaccinated Population in {country}')
    plt.show()

# %%
import plotly.express as px

# Prepare the dataframe with iso_code and total_cases for the latest date
latest_data = df_cleaned[df_cleaned['date'] == df_cleaned['date'].max()]
choropleth_data = latest_data[['iso_code', 'total_cases']].dropna()

# Plot the choropleth map
fig = px.choropleth(
    choropleth_data,
    locations="iso_code",
    color="total_cases",
    hover_name="iso_code",
    title="COVID-19 Total Cases by Country",
    color_continuous_scale=px.colors.sequential.Plasma
)

fig.update_geos(showcoastlines=True, coastlinecolor="LightGray")
fig.show()

# %%
# Insights & Reporting

## Key Insights

1. **Vaccination Rates**:
    - The United States has the highest percentage of vaccinated population among the selected countries, with approximately 79.88% of its population vaccinated.
    - India follows with 72.50% of its population vaccinated, while Kenya lags behind at 26.83%.

2. **COVID-19 Cases Over Time**:
    - The United States experienced the highest total number of COVID-19 cases among the selected countries, with over 103 million cases reported as of the latest date.
    - India and Kenya reported significantly lower total cases, with India at approximately 39 billion and Kenya at 297 million.

3. **Cumulative Vaccinations**:
    - India has administered the highest number of total vaccinations, surpassing 2.2 billion doses, followed by the United States with over 676 million doses.

4. **Anomalies in Data**:
    - Kenya s vaccination data shows a significant gap compared to India and the United States, indicating potential challenges in vaccine distribution or reporting.
    - Some countries, such as Kenya, have missing data for certain metrics like ICU admissions and testing rates, which could impact the accuracy of insights.

5. **Global Trends**:
    - The global cumulative total cases have reached over 771 million, with significant disparities in case distribution and vaccination rates across continents.

## Interesting Patterns

- **Vaccination Rollout**:
  - The United States and India show a consistent and rapid vaccine rollout, while Kenya s vaccination progress appears slower, potentially due to resource constraints.

- **Testing and Reporting**:
  - The dataset highlights missing or incomplete data for several metrics, such as ICU admissions and testing rates, particularly for lower-income countries.

- **Mortality Rates**:
  - Despite having a high number of cases, the United States has managed to maintain a relatively low death rate compared to its total cases, indicating effective healthcare interventions.

## Recommendations

- Focus on improving data collection and reporting for countries with missing or incomplete data to ensure more accurate insights.
- Investigate the factors contributing to Kenya s slower vaccination progress and address potential barriers to vaccine access.
- Continue monitoring global trends to identify emerging hotspots and allocate resources effectively.
# Out:
#   Cell In[20], line 5
#     1. **Vaccination Rates**:
#                      ^
# SyntaxError: invalid syntax
